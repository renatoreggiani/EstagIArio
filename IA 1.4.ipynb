# %%
#@autor Gustavo Moss /Renato Regianne
import speech_recognition as sr
from gtts import gTTS
from unicodedata import normalize
from playsound import playsound
import os
import sys
from diretorio.comandos import *
import spacy
from nltk import RSLPStemmer
from abc import ABCMeta, abstractmethod
nlp = spacy.load('pt_core_news_sm')
from Interpretador import *
# Out:
# achei data

# %%
class ComunicacaoEstagiario(object):
    
    def cria_audio(audio):
        tts = gTTS(audio,lang='pt-br')
        #Salva o arquivo de audio
        tts.save('/home/moss/IA/teste.mp3')
        print("sim mestre")
        #Da play ao audio
        playsound('/home/moss/IA/teste.mp3')

    
    def ouvir_microfone():
        """Funcao responsavel por ouvir e reconhecer a fala"""
        microfone = sr.Recognizer()  # Habilita o microfone para ouvir o usuario
        with sr.Microphone() as source:
            microfone.adjust_for_ambient_noise(source)  # Chama a funcao de reducao de ruido
            print("Diga alguma coisa: ")
            #microfone.record(source,duration=None)#grava o audio ate nao haver mais( fala em teste)
            audio = microfone.listen(source,timeout=None)  # Armazena a informacao de audio na variavel
            
        try:
            texto = microfone.recognize_google(audio, language='pt-BR')  # Transforma audio em texto
#             if 'estagiário' in texto.lower():
#                 texto = texto.replace('estagiário', '').strip()
#                 print("Você disse: " + texto)
#                 return texto
#           mais pratico pra testar
            print("Você disse: " + texto)
            return texto.lower()
        # Caso nao tenha reconhecido o padrao de fala, exibe esta mensagem
        except sr.WaitTimeoutError:
            print("Não entendi")

# %%
class ComandosEstagiario(object):
        
        __metaclass__=ABCMeta
        
        @abstractmethod
        def _listaDeComandos():
            pass
        
        
        def __selecionaComando(self,comando):
            comandos=self.listaDeComandos()
            if comando in comandos.keys():
                return True
    
        @staticmethod
        def __identificaComando(frase):
            cmd=identifica_comando(frase)
            return cmd
            
            
        def _executaComando(self,voz):
            comando=ComandosEstagiario.__identificaComando(voz)
            if self.__selecionaComando(comando):
                return eval(f'{comando}()')     
            else:
                #vai ter uma funcao pra ele falar(audio)
                print('desculpe mestre eu nao sei fazer isso,sei fazer apenas isso:\n')
                return list_com()

# %%
class Estagiario(ComandosEstagiario,ComunicacaoEstagiario):
    
    def __init__(self):
        self._listaDeComandos=self._manipulaListaDeComandos()
         
    
    def _manipulaListaDeComandos(self):
            with open('listaDeComandos.txt','r') as arquivo:
                dic=arquivo.read()
                dic=eval(dic)
            return dic
        
    def listaDeComandos(self):
        return self._listaDeComandos
        
    def interface(self):
        frase=Estagiario.ouvir_microfone() #automatizado 
        #frase=input('comando:')#manual para testes 
        print(self._executaComando(frase))
        self.interface()

# %%
if __name__ == '__main__':
    e=Estagiario()

    e.interface()
# Out:
# Diga alguma coisa:
# Você disse: tomar conta
# desculpe mestre eu nao sei fazer isso,sei fazer apenas isso:
#
# comando:somar conta
# funcao:soma dois numeros
#
# comando:subtrair conta
# funcao:subtrai dois numeros
#
# comando:abrir site
# funcao:abre um site
#
# comando:finalizar sistema
# funcao:finaliza o estagiario
#
# comando:lista de comandos
# funcao:exibi lista de comandos
#
# None
# Diga alguma coisa:
# Você disse: tomar conta
# desculpe mestre eu nao sei fazer isso,sei fazer apenas isso:
#
# comando:somar conta
# funcao:soma dois numeros
#
# comando:subtrair conta
# funcao:subtrai dois numeros
#
# comando:abrir site
# funcao:abre um site
#
# comando:finalizar sistema
# funcao:finaliza o estagiario
#
# comando:lista de comandos
# funcao:exibi lista de comandos
#
# None
# Diga alguma coisa:
# Você disse: somar conta
# 2
# Diga alguma coisa:
# Você disse: lista de comandos
# comando:somar conta
# funcao:soma dois numeros
#
# comando:subtrair conta
# funcao:subtrai dois numeros
#
# comando:abrir site
# funcao:abre um site
#
# comando:finalizar sistema
# funcao:finaliza o estagiario
#
# comando:lista de comandos
# funcao:exibi lista de comandos
#
# None
# Diga alguma coisa:
# Você disse: tô chegando
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-c2ca9f71eece> in <module>()
#       2     e=Estagiario()
#       3
# ----> 4     e.interface()
#
# <ipython-input-4-0f46af14d9d6> in interface(self)
#      18         #frase=input('comando:')#manual para testes
#      19         print(self._executaComando(frase))
# ---> 20         self.interface()
#
# <ipython-input-4-0f46af14d9d6> in interface(self)
#      18         #frase=input('comando:')#manual para testes
#      19         print(self._executaComando(frase))
# ---> 20         self.interface()
#
# <ipython-input-4-0f46af14d9d6> in interface(self)
#      18         #frase=input('comando:')#manual para testes
#      19         print(self._executaComando(frase))
# ---> 20         self.interface()
#
# <ipython-input-4-0f46af14d9d6> in interface(self)
#      18         #frase=input('comando:')#manual para testes
#      19         print(self._executaComando(frase))
# ---> 20         self.interface()
#
# <ipython-input-4-0f46af14d9d6> in interface(self)
#      17         frase=Estagiario.ouvir_microfone() #automatizado
#      18         #frase=input('comando:')#manual para testes
# ---> 19         print(self._executaComando(frase))
#      20         self.interface()
#
# <ipython-input-3-2f9de9bae8d5> in _executaComando(self, voz)
#      26
#      27         def _executaComando(self,voz):
# ---> 28             comando=ComandosEstagiario.__identificaComando(voz)
#      29             if self.__selecionaComando(comando):
#      30                 return eval(f'{comando}()')
#
# <ipython-input-3-2f9de9bae8d5> in __identificaComando(frase)
#      19             dic_cmd = {'index_acao':[palavra.i for palavra in doc if palavra.dep_ == 'ROOT'][0]}
#      20             dic_cmd['acao'] = doc[dic_cmd['index_acao']].orth_
# ---> 21             dic_cmd['comp_acao'] = [palavra.orth_ for palavra in doc[dic_cmd['index_acao']].rights][0]
#      22             cmd = '_'.join([stemmer.stem(dic_cmd['acao']),
#      23                             stemmer.stem(dic_cmd['comp_acao'])])
#
# IndexError: list index out of range
